# %% [markdown]
# <a href="https://colab.research.google.com/github/RostislavKorst/Generative-Models-2023/blob/main/Assignment%203/3_tricks_metrics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Generative Models
# ***
#
# **Autumn 2023, MSc course**

# %% [markdown]
# ## Assignment 3
#
# ***
#
#
# *Authored by Arip Asadulaev & Manh Lab*
#
# *Adapted by Rostislav Korst*
#
# ***

# %% [markdown]
# ### Метрики качества генерации:

# %% [markdown]
# IS
#
# ![IS.png](data:image/png;base64,...)

# %% [markdown]
# Для оценки метрики, называемой Inception score (IS), применяется классификатор Inception model, обученный на датасете ImageNet.
#
# С помощью классификации сгенерированных изображений данной внешней моделью получается условное распределение лейблов от картинок $p(y|\mathbf{x})$. Сгенерированные картинки, похожие на что-то реальное из классов, которые есть в ImageNet, должны иметь распределение $p(y|x)$ с низкой энтропией:
#
# \begin{equation}
#     H(x) = - \sum_{i=1}^{n} p_i \log p_i
# \end{equation}
#
# То есть модель должна быть уверена, что на картинке изображена, например, собака.
#
# Однако также сгенерированные изображения должны быть разнообразны, то есть наша модель генерации должна генерировать и кошек, и собак, и машины, а не только один какой-то понравившийся ей класс. Поэтому энтропия маргинализованного по пространству картинок распределения должна быть высокой.
#
# \begin{equation}
#     p(y) = \int_X p(y|x) dx
# \end{equation}
#
# Комбинируя эти два требования, получается метрика, которая меряет расстояние между двумя распределениями. Чем это расстояние больше, тем лучше. Метрика IS дается выражением:
#
# \begin{equation}
#     IS = exp \left( \mathbb{E}_{x \sim p_g} D_{KL}(p(y|x) \parallel p(y)) \right)
# \end{equation}
#
# где $D_{KL}$ - KL-дивергенция. $p_g$ - распределение сгенерированных изображений.

# %% [markdown]
# FID
#
# ![FID.png](data:image/png;base64,...)

# %% [markdown]
# Минусом метрики IS является то, что она никак не учитывает распределение реальных данных для оценки качества сгенерированных изображений. Поэтому была предложена другая метрика Fréchet inception distance (FID).
#
# Мотивация этой метрики состоит в том, чтобы сравнить распределения реальных и сгенерированных данных, или, другими словами, померить расстояние между двумя распределениями. Но измерения производятся не на самом распределении данных, а на некотором извлеченном из картинок представлении. Для этого каждое из сгенерированных изображений подается в модель Inception model (аналогично Inception Score), последний слой пуллинга (последний слой перед линейным преобразованием в логиты классификатора) которой выступает в качестве представления изображений. Inception v3 network, используемая для расчета обоих метрик, - это конкретная модель, поэтому можно сказать, что представление изображений в ней - это вектор длиной 2048. Представление получается также и для изображений исходного датасета.
#
#
# Распределения двух полученных представлений упрощенно рассматриваются как многомерные Гауссианы, расстояние между которыми можно померить с помощью Fréchet distance.
#
# Для одномерного нормального распределения расстояние будет выглядеть следующим образом:
#
# \begin{equation}
#     d(X, Y) = (\mu_X - \mu_Y)^2 + (\sigma_X - \sigma_Y)^2 = (\mu_X - \mu_Y)^2 + (\sigma^2_X + \sigma^2_Y - 2\sigma_X \sigma_Y)
# \end{equation}
#
# Для многомерного нормального распределения формула расстояния следующая:
#
# \begin{equation}
#     d(X, Y) = \| \mathbf{\mu}_X - \mathbf{\mu}_Y \|^2 + Tr(\mathbf{\Sigma}_X + \mathbf{\Sigma}_Y - 2\sqrt{\mathbf{\Sigma}_X \mathbf{\Sigma}_Y})
# \end{equation}
#
# Соответственно, FID показывает расстояние между сгенерированными изображениями и исходным реальным датасетом, поэтому, чем меньше расстояние, тем сгенерированные изображения лучше.

# %% [markdown]
# ### Задание:
#
# В данном задании нужно будет
#
# * Обучить GAN на датасете CIFAR10, используя методы регуляризации: label smoothing, spectral normalization, подача шума на дискриминатор поверх сгенерированных и реальных данных.
#
# * Замерить качество генерации изображений с помощью метрик IS и FID. Привести примеры генерации и таблицу с результатами обучения моделей без регуляризаций и с различными их комбинациями (хотя бы одной). Сравните метрики сгенерированных изображений с метриками исходного датасета.
#
# Пример таблицы:
#
#
#
# Model | IS $⇑$ | FID $⇓$ |
# ---------|------|-----------|
# DCGAN | |
# Label Smoothing (LS) |  |
# Spectral Normalization (SN) |  |
# DCGAN + LS + SN | |
# CIFAR10 | 10.98 ± 0.22 | 3.1508

# %% [markdown]
# ### Define parameters & Load Dataset

# %%
import torch
import torch.nn as nn
import numpy as np
import cv2
import matplotlib.pyplot as plt
import torchvision
from torchvision import transforms
from torchvision.transforms import ToTensor, Normalize, Compose
from torchvision.datasets import MNIST, CIFAR10
from IPython.display import Image
from torchvision.utils import save_image
import os
# %matplotlib inline
plt.style.use("ggplot")

class CFG:
    batch_size = 128
    num_epochs = 300
    workers = 4
    seed = 2021
    image_size = 64
    download = True
    dataroot = "data"
    nc = 3  ## number of chanels
    ngf = 64  # Size of feature maps in generator
    nz = 100  # latent random input vector
    ndf = 64  # Size of feature maps in discriminator
    lr = 0.0002
    device = "cuda" if torch.cuda.is_available() else "cpu"
    sample_dir = "./images/"


if not os.path.exists(CFG.sample_dir):
    os.makedirs(CFG.sample_dir)

cifar_dataset = CIFAR10(
    root=CFG.dataroot,
    download=CFG.download,
    transform=transforms.Compose(
        [
            transforms.Resize([CFG.image_size, CFG.image_size]),
            transforms.ToTensor(),
            transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
        ]
    ),
)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to data/cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:08<00:00, 20848266.35it/s]
# Extracting data/cifar-10-python.tar.gz to data

# %%
img, label = cifar_dataset[0]
print("Label: ", label)
plt.hist(img[:, :, :].flatten(), bins=15)
# Out:
# Label:  6
# (array([ 140.,  578., 1378., 1406., 1163., 1691., 1246., 1402., 1351.,
#          602.,  440.,  344.,  279.,  185.,   83.]),
#  array([-0.99215686, -0.86091501, -0.72967321, -0.59843135, -0.46718955,
#         -0.33594772, -0.20470588, -0.07346405,  0.05777778,  0.18901961,
#          0.32026145,  0.45150328,  0.58274508,  0.71398693,  0.84522873,
#          0.97647059]),
#  <BarContainer object of 15 artists>)

# %%
# unnormalization image from range (-1)-1 to range 0-1 to display it
def denorm(x):
  return (x + 1) / 2

# show  image sample with matplotlib
img = denorm(img).numpy().transpose(1, 2, 0)
plt.imshow(img)

# %%
# define the dataloader
from torch.utils.data import DataLoader

data_loader = DataLoader(
    cifar_dataset,
    batch_size=CFG.batch_size,
    shuffle=True,
    num_workers=CFG.workers,
    pin_memory=True
)

# %% [markdown]
# # Спектральная нормализация

# %%
import torch
from torch.optim.optimizer import Optimizer, required

from torch.autograd import Variable
import torch.nn.functional as F
from torch import nn
from torch import Tensor
from torch.nn import Parameter

def l2normalize(v, eps=1e-12):
    return v / (v.norm() + eps)


class SpectralNorm(nn.Module):
    def __init__(self, module, name='weight', power_iterations=1):
        super(SpectralNorm, self).__init__()
        self.module = module
        self.name = name
        self.power_iterations = power_iterations
        if not self._made_params():
            self._make_params()

    def _update_u_v(self):
        u = getattr(self.module, self.name + "_u")
        v = getattr(self.module, self.name + "_v")
        w = getattr(self.module, self.name + "_bar")

        height = w.data.shape[0]
        for _ in range(self.power_iterations):
            v.data = l2normalize(torch.mv(torch.t(w.view(height,-1).data), u.data))
            u.data = l2normalize(torch.mv(w.view(height,-1).data, v.data))

        # sigma = torch.dot(u.data, torch.mv(w.view(height,-1).data, v.data))
        sigma = u.dot(w.view(height, -1).mv(v))
        setattr(self.module, self.name, w / sigma.expand_as(w))

    def _made_params(self):
        try:
            u = getattr(self.module, self.name + "_u")
            v = getattr(self.module, self.name + "_v")
            w = getattr(self.module, self.name + "_bar")
            return True
        except AttributeError:
            return False


    def _make_params(self):
        w = getattr(self.module, self.name)

        height = w.data.shape[0]
        width = w.view(height, -1).data.shape[1]

        u = Parameter(w.data.new(height).normal_(0, 1), requires_grad=False)
        v = Parameter(w.data.new(width).normal_(0, 1), requires_grad=False)
        u.data = l2normalize(u.data)
        v.data = l2normalize(v.data)
        w_bar = Parameter(w.data)

        del self.module._parameters[self.name]

        self.module.register_parameter(self.name + "_u", u)
        self.module.register_parameter(self.name + "_v", v)
        self.module.register_parameter(self.name + "_bar", w_bar)


    def forward(self, *args):
        self._update_u_v()
        return self.module.forward(*args)

# %% [markdown]
# ## Tricks
# - use deeper CNN
# - use LeakyRELU instead of ReLU
# - use BatchNorm, Dropout
# - SpectralNorm

# %%
import torch.nn as nn
# Generator
class Generator(nn.Module):
    def __init__(self, nz, ngf, nc):
        super(Generator, self).__init__()
        self.nz = nz
        self.main = nn.Sequential(
            # Входной слой
            nn.ConvTranspose2d(nz, ngf * 8, 4, 1, 0, bias=False),
            nn.BatchNorm2d(ngf * 8),
            nn.ReLU(True),

            # Слой для размера (ngf*8) x 8 x 8
            nn.ConvTranspose2d(ngf * 8, ngf * 4, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ngf * 4),
            nn.ReLU(True),

            # Слой для размера (ngf*4) x 16 x 16
            nn.ConvTranspose2d(ngf * 4, ngf * 2, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ngf * 2),
            nn.ReLU(True),

            # Слой для размера (ngf*2) x 32 x 32
            nn.ConvTranspose2d(ngf * 2, ngf, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ngf),
            nn.ReLU(True),

            # Финальный слой для размера (nc) x 64 x 64
            nn.ConvTranspose2d(ngf, nc, 4, 2, 1, bias=False),
            nn.Tanh()
        )

    def forward(self, input):
        input = input.view(-1, self.nz, 1, 1)
        return self.main(input)


# Discriminator

class Discriminator(nn.Module):
    def __init__(self, nc, ndf):
        super(Discriminator, self).__init__()
        self.main = nn.Sequential(
            # Убедитесь, что размеры каналов согласованы
            SpectralNorm(nn.Conv2d(nc, ndf, 4, 2, 1, bias=False)),
            nn.LeakyReLU(0.3, inplace=True),
            nn.Dropout(0.5),  # Dropout layer

            SpectralNorm(nn.Conv2d(ndf, ndf * 2, 4, 2, 1, bias=False)),
            nn.BatchNorm2d(ndf * 2),
            nn.LeakyReLU(0.3, inplace=True),
            nn.Dropout(0.5),

            SpectralNorm(nn.Conv2d(ndf * 2, ndf * 4, 4, 2, 1, bias=False)),
            nn.BatchNorm2d(ndf * 4),
            nn.LeakyReLU(0.3, inplace=True),
            nn.Dropout(0.5),

            SpectralNorm(nn.Conv2d(ndf * 4, ndf * 8, 4, 2, 1, bias=False)),
            nn.BatchNorm2d(ndf * 8),
            nn.LeakyReLU(0.3, inplace=True),
            nn.Dropout(0.5),

            # Финальный слой должен учитывать размеры предыдущего слоя
            SpectralNorm(nn.Conv2d(ndf * 8, 1, 4, 1, 0, bias=False)),
            nn.Sigmoid()
        )

    def forward(self, input):
        output = self.main(input)
        return output.view(-1, 1)

# %%
G = Generator(CFG.nz, CFG.ngf, CFG.nc).to(CFG.device)
D = Discriminator(CFG.nc, CFG.ndf).to(CFG.device)

# %%
# show the output of model
y = G(torch.randn(2, CFG.nz).to(CFG.device))

# %%
y.shape
# Out:
# torch.Size([2, 3, 64, 64])

# %% [markdown]
# Discriminator Training

# %%
# Label Smoothing, i.e. if you have two target labels: Real=1 and Fake=0, then for each incoming sample,
#  if it is real, then replace the label with a random number between 0.7 and 1.2, and
#  if it is a fake sample, replace it with 0.0 and 0.3 (for example).
#make the labels the noisy for the discriminator: occasionally flip the labels when training the discriminator

# %%
def reset_grad(opt_g, opt_d):
    opt_g.zero_grad()
    opt_d.zero_grad()

def train_discriminator(images, batch_size, latent_size, G, D, criterion, opt_d, device, label_smoothing=True, label_flipping=0.05):
    # Label Smoothing
    if label_smoothing:
        # Smooth labels for real images: Random number between 0.7 and 1.2
        real_labels = (0.7 - 1.2) * torch.rand(batch_size, 1).to(device) + 1.2
        # Smooth labels for fake images: Random number between 0.0 and 0.3
        fake_labels = (0.0 - 0.3) * torch.rand(batch_size, 1).to(device)
    else:
        real_labels = torch.ones(batch_size, 1).to(device)
        fake_labels = torch.zeros(batch_size, 1).to(device)

    # Label Flipping
    if label_flipping > 0:
        for i in range(batch_size):
            if torch.rand(1).item() < label_flipping:
                real_labels[i] = 1 - real_labels[i]
                fake_labels[i] = 1 - fake_labels[i]

    # Train with real images
    D.zero_grad()
    outputs = D(images)
    d_loss_real = criterion(outputs, real_labels)
    real_score = outputs

    # Train with fake images
    z = torch.randn(batch_size, latent_size).to(device)
    fake_images = G(z)
    outputs = D(fake_images.detach())
    d_loss_fake = criterion(outputs, fake_labels)
    fake_score = outputs

    # Sum up losses and backpropagate
    d_loss = d_loss_real + d_loss_fake
    d_loss.backward()
    opt_d.step()

    return d_loss, real_score, fake_score

# %% [markdown]
# Generator Training

# %%
#Add gauss noise
#noise = 0.005*np.random.uniform()*np.amax(sound)

# %%
def train_generator(batch_size, latent_size, G, D, criterion, opt_g, device):
    # Generate fake images and calculate loss
    z = np.random.normal(0, 1, (batch_size, latent_size))
    noise = 0.005 * np.random.uniform() * np.amax(z)
    z = z.astype('float64') + noise * np.random.normal(size=z.shape)
    z = torch.Tensor(z).to(device)

    # Generate fake images
    fake_images = G(z)

    # Create labels for fake images as real (for generator training)
    labels = torch.ones(batch_size, 1).to(device)

    # Calculate the generator loss
    outputs = D(fake_images)
    g_loss = criterion(outputs, labels)

    # Reset gradients
    opt_g.zero_grad()

    # Backpropagation
    g_loss.backward()

    # Optimize the generator
    opt_g.step()

    return g_loss, fake_images

# %% [markdown]
# ## Start the training process

# %%
def save_fake_images(index):
    z = np.random.normal(0, 1, (batch_size, CFG.nz))
    noise = 0.005 * np.random.uniform() * np.amax(z)
    z = z.astype('float64') + noise * np.random.normal(size=z.shape)
    z = torch.Tensor(z).to(device)
    fake_images = G(z)

    fake_fname = f'fake_images-{index:04d}.png'
    print('Saving', fake_fname)
    save_image(fake_images, os.path.join(CFG.sample_dir, fake_fname), nrow=10)

# %%
import torch.optim as optim
import torch.nn as nn

criterion = nn.BCELoss()

# Define the optimizer for the generator
optimizer_G = optim.Adam(G.parameters(), lr=CFG.lr)

# Define the optimizer for the discriminator
optimizer_D = optim.Adam(D.parameters(), lr=CFG.lr / 2)

# %%
3576704, 2781937

# %%
# %%time
device = CFG.device
num_epochs = CFG.num_epochs
batch_size = CFG.batch_size
latent_size = CFG.nz  # Assuming the latent vector size is stored in CFG.nz

total_step = len(data_loader)
d_losses, g_losses, real_scores, fake_scores = [], [], [], []
G.to(device)
D.to(device)

for epoch in range(num_epochs):
    for i, (images, _) in enumerate(data_loader):
        images = images.to(device)
        current_batch_size = images.size(0)  # Adjusting batch size for last batch

        if i % 2 == 0:
            d_loss, real_score, fake_score = train_discriminator(images, current_batch_size, latent_size, G, D, criterion, optimizer_D, device)
            reset_grad(optimizer_G, optimizer_D)

        g_loss, fake_images = train_generator(current_batch_size, latent_size, G, D, criterion, optimizer_G, device)
        reset_grad(optimizer_G, optimizer_D)
        # Logging the losses and scores
        if (i + 1) % 200 == 0:
            d_losses.append(d_loss.item())
            g_losses.append(g_loss.item())
            real_scores.append(real_score.mean().item())
            fake_scores.append(fake_score.mean().item())
            print(f'Epoch [{epoch+1}/{num_epochs}], Step [{i+1}/{total_step}], d_loss: {d_loss.item():.4f}, g_loss: {g_loss.item():.4f}, D(x): {real_score.mean():.2f}, D(G(z)): {fake_score.mean():.2f}')

    # Save fake images for visualization
    save_fake_images(epoch + 1)
# Out:
# Epoch [1/300], Step [200/391], d_loss: 1.2232, g_loss: 3.2707, D(x): 0.65, D(G(z)): 0.27
# Saving fake_images-0001.png
# Epoch [2/300], Step [200/391], d_loss: 1.3037, g_loss: 2.7181, D(x): 0.45, D(G(z)): 0.26
# Saving fake_images-0002.png
# Epoch [3/300], Step [200/391], d_loss: 1.3587, g_loss: 1.8528, D(x): 0.52, D(G(z)): 0.33
# Saving fake_images-0003.png
# Epoch [4/300], Step [200/391], d_loss: 1.2082, g_loss: 2.0467, D(x): 0.48, D(G(z)): 0.24
# Saving fake_images-0004.png
# Epoch [5/300], Step [200/391], d_loss: 1.4023, g_loss: 1.9603, D(x): 0.53, D(G(z)): 0.34
# Saving fake_images-0005.png
# Epoch [6/300], Step [200/391], d_loss: 1.9961, g_loss: 1.2578, D(x): 0.46, D(G(z)): 0.43
# Saving fake_images-0006.png
# Epoch [7/300], Step [200/391], d_loss: 0.9793, g_loss: 1.9980, D(x): 0.71, D(G(z)): 0.29
# Saving fake_images-0007.png
# Epoch [8/300], Step [200/391], d_loss: 0.9517, g_loss: 2.2564, D(x): 0.63, D(G(z)): 0.18
# Saving fake_images-0008.png
# Epoch [9/300], Step [200/391], d_loss: 0.8485, g_loss: 2.2411, D(x): 0.60, D(G(z)): 0.20
# Saving fake_images-0009.png
# Epoch [10/300], Step [200/391], d_loss: 1.6209, g_loss: 1.1668, D(x): 0.47, D(G(z)): 0.40
# Saving fake_images-0010.png
# Epoch [11/300], Step [200/391], d_loss: 1.5555, g_loss: 1.0718, D(x): 0.46, D(G(z)): 0.40
# Saving fake_images-0011.png
# Epoch [12/300], Step [200/391], d_loss: 2.0410, g_loss: 1.1764, D(x): 0.37, D(G(z)): 0.46
# Saving fake_images-0012.png
# Epoch [13/300], Step [200/391], d_loss: 1.4481, g_loss: 1.3541, D(x): 0.41, D(G(z)): 0.31
# Saving fake_images-0013.png
# Epoch [14/300], Step [200/391], d_loss: 1.1401, g_loss: 1.5075, D(x): 0.50, D(G(z)): 0.29
# Saving fake_images-0014.png
# Epoch [15/300], Step [200/391], d_loss: 1.5077, g_loss: 1.0798, D(x): 0.41, D(G(z)): 0.39
# Saving fake_images-0015.png
# Epoch [16/300], Step [200/391], d_loss: 1.4844, g_loss: 1.1308, D(x): 0.43, D(G(z)): 0.38
# Saving fake_images-0016.png
# Epoch [17/300], Step [200/391], d_loss: 1.9654, g_loss: 1.0036, D(x): 0.34, D(G(z)): 0.49
# Saving fake_images-0017.png
# Epoch [18/300], Step [200/391], d_loss: 1.6344, g_loss: 0.9573, D(x): 0.44, D(G(z)): 0.43
# Saving fake_images-0018.png
# Epoch [19/300], Step [200/391], d_loss: 1.6170, g_loss: 1.3533, D(x): 0.36, D(G(z)): 0.31
# Saving fake_images-0019.png
# Epoch [20/300], Step [200/391], d_loss: 1.6378, g_loss: 0.9479, D(x): 0.39, D(G(z)): 0.44
# Saving fake_images-0020.png
# Epoch [21/300], Step [200/391], d_loss: 1.5023, g_loss: 0.9350, D(x): 0.43, D(G(z)): 0.44
# Saving fake_images-0021.png
# Epoch [22/300], Step [200/391], d_loss: 1.0707, g_loss: 1.6527, D(x): 0.48, D(G(z)): 0.25
# Saving fake_images-0022.png
# Epoch [23/300], Step [200/391], d_loss: 1.8472, g_loss: 1.5418, D(x): 0.32, D(G(z)): 0.30
# Saving fake_images-0023.png
# Epoch [24/300], Step [200/391], d_loss: 1.4760, g_loss: 1.2240, D(x): 0.43, D(G(z)): 0.38
# Saving fake_images-0024.png
# Epoch [25/300], Step [200/391], d_loss: 1.3376, g_loss: 0.9947, D(x): 0.49, D(G(z)): 0.41
# Saving fake_images-0025.png
# Epoch [26/300], Step [200/391], d_loss: 1.4209, g_loss: 0.9419, D(x): 0.50, D(G(z)): 0.43
# Saving fake_images-0026.png
# Epoch [27/300], Step [200/391], d_loss: 1.7036, g_loss: 0.8898, D(x): 0.43, D(G(z)): 0.50
# Saving fake_images-0027.png
# Epoch [28/300], Step [200/391], d_loss: 1.3897, g_loss: 0.9264, D(x): 0.53, D(G(z)): 0.47
# Saving fake_images-0028.png
# Epoch [29/300], Step [200/391], d_loss: 1.4319, g_loss: 1.0768, D(x): 0.47, D(G(z)): 0.39
# Saving fake_images-0029.png
# Epoch [30/300], Step [200/391], d_loss: 1.4843, g_loss: 1.2455, D(x): 0.39, D(G(z)): 0.37
# Saving fake_images-0030.png
# Epoch [31/300], Step [200/391], d_loss: 1.3851, g_loss: 0.9818, D(x): 0.42, D(G(z)): 0.40
# Saving fake_images-0031.png
# Epoch [32/300], Step [200/391], d_loss: 1.4931, g_loss: 0.9390, D(x): 0.48, D(G(z)): 0.44
# Saving fake_images-0032.png
# Epoch [33/300], Step [200/391], d_loss: 1.3354, g_loss: 1.0856, D(x): 0.48, D(G(z)): 0.39
# Saving fake_images-0033.png
# Epoch [34/300], Step [200/391], d_loss: 1.6805, g_loss: 0.7848, D(x): 0.38, D(G(z)): 0.46
# Saving fake_images-0034.png
# Epoch [35/300], Step [200/391], d_loss: 1.5540, g_loss: 0.8874, D(x): 0.39, D(G(z)): 0.44
# Saving fake_images-0035.png
# Epoch [36/300], Step [200/391], d_loss: 1.1416, g_loss: 1.1935, D(x): 0.49, D(G(z)): 0.33
# Saving fake_images-0036.png
# Epoch [37/300], Step [200/391], d_loss: 1.5110, g_loss: 0.9195, D(x): 0.43, D(G(z)): 0.44
# Saving fake_images-0037.png
# Epoch [38/300], Step [200/391], d_loss: 1.4596, g_loss: 1.1033, D(x): 0.42, D(G(z)): 0.42
# Saving fake_images-0038.png
# Epoch [39/300], Step [200/391], d_loss: 1.4796, g_loss: 0.8523, D(x): 0.40, D(G(z)): 0.44
# Saving fake_images-0039.png
# Epoch [40/300], Step [200/391], d_loss: 1.3837, g_loss: 1.0203, D(x): 0.38, D(G(z)): 0.36
# Saving fake_images-0040.png
# Epoch [41/300], Step [200/391], d_loss: 1.2738, g_loss: 1.1498, D(x): 0.39, D(G(z)): 0.34
# Saving fake_images-0041.png
# Epoch [42/300], Step [200/391], d_loss: 1.4793, g_loss: 1.0150, D(x): 0.40, D(G(z)): 0.41
# Saving fake_images-0042.png
# Epoch [43/300], Step [200/391], d_loss: 1.1942, g_loss: 1.0163, D(x): 0.51, D(G(z)): 0.40
# Saving fake_images-0043.png
# Epoch [44/300], Step [200/391], d_loss: 1.3469, g_loss: 1.0924, D(x): 0.43, D(G(z)): 0.39
# Saving fake_images-0044.png
# Epoch [45/300], Step [200/391], d_loss: 1.4151, g_loss: 0.9993, D(x): 0.41, D(G(z)): 0.41
# Saving fake_images-0045.png
# Epoch [46/300], Step [200/391], d_loss: 1.5171, g_loss: 1.0249, D(x): 0.36, D(G(z)): 0.37
# Saving fake_images-0046.png
# Epoch [47/300], Step [200/391], d_loss: 1.3019, g_loss: 0.9653, D(x): 0.46, D(G(z)): 0.38
# Saving fake_images-0047.png
# Epoch [48/300], Step [200/391], d_loss: 1.3219, g_loss: 1.1629, D(x): 0.43, D(G(z)): 0.37
# Saving fake_images-0048.png
# Epoch [49/300], Step [200/391], d_loss: 1.1289, g_loss: 1.2900, D(x): 0.44, D(G(z)): 0.29
# Saving fake_images-0049.png
# Epoch [50/300], Step [200/391], d_loss: 1.2643, g_loss: 1.3729, D(x): 0.42, D(G(z)): 0.29
# Saving fake_images-0050.png
# Epoch [51/300], Step [200/391], d_loss: 1.4210, g_loss: 1.1592, D(x): 0.40, D(G(z)): 0.36
# Saving fake_images-0051.png
# Epoch [52/300], Step [200/391], d_loss: 1.4472, g_loss: 1.0071, D(x): 0.39, D(G(z)): 0.37
# Saving fake_images-0052.png
# Epoch [53/300], Step [200/391], d_loss: 1.4844, g_loss: 0.8511, D(x): 0.44, D(G(z)): 0.44
# Saving fake_images-0053.png
# Epoch [54/300], Step [200/391], d_loss: 1.6976, g_loss: 0.8033, D(x): 0.39, D(G(z)): 0.48
# Saving fake_images-0054.png
# Epoch [55/300], Step [200/391], d_loss: 1.4805, g_loss: 1.0248, D(x): 0.36, D(G(z)): 0.38
# Saving fake_images-0055.png
# Epoch [56/300], Step [200/391], d_loss: 1.4687, g_loss: 0.9568, D(x): 0.38, D(G(z)): 0.40
# Saving fake_images-0056.png
# Epoch [57/300], Step [200/391], d_loss: 1.2260, g_loss: 1.0206, D(x): 0.47, D(G(z)): 0.38
# Saving fake_images-0057.png
# Epoch [58/300], Step [200/391], d_loss: 1.5456, g_loss: 1.0264, D(x): 0.36, D(G(z)): 0.41
# Saving fake_images-0058.png
# Epoch [59/300], Step [200/391], d_loss: 1.3672, g_loss: 0.9807, D(x): 0.46, D(G(z)): 0.43
# Saving fake_images-0059.png
# Epoch [60/300], Step [200/391], d_loss: 1.2622, g_loss: 1.0936, D(x): 0.44, D(G(z)): 0.37
# Saving fake_images-0060.png
# Epoch [61/300], Step [200/391], d_loss: 1.4423, g_loss: 0.9876, D(x): 0.42, D(G(z)): 0.42
# Saving fake_images-0061.png
# Epoch [62/300], Step [200/391], d_loss: 1.3930, g_loss: 0.8532, D(x): 0.46, D(G(z)): 0.42
# Saving fake_images-0062.png
# Epoch [63/300], Step [200/391], d_loss: 1.3814, g_loss: 1.0769, D(x): 0.41, D(G(z)): 0.36
# Saving fake_images-0063.png
# Epoch [64/300], Step [200/391], d_loss: 1.1501, g_loss: 1.0287, D(x): 0.50, D(G(z)): 0.36
# Saving fake_images-0064.png
# Epoch [65/300], Step [200/391], d_loss: 1.3079, g_loss: 0.9864, D(x): 0.47, D(G(z)): 0.41
# Saving fake_images-0065.png
# Epoch [66/300], Step [200/391], d_loss: 1.2513, g_loss: 0.9337, D(x): 0.49, D(G(z)): 0.42
# Saving fake_images-0066.png
# Epoch [67/300], Step [200/391], d_loss: 1.3336, g_loss: 1.0244, D(x): 0.43, D(G(z)): 0.40
# Saving fake_images-0067.png
# Epoch [68/300], Step [200/391], d_loss: 1.6129, g_loss: 0.9394, D(x): 0.33, D(G(z)): 0.40
# Saving fake_images-0068.png
# Epoch [69/300], Step [200/391], d_loss: 1.3154, g_loss: 1.0420, D(x): 0.45, D(G(z)): 0.40
# Saving fake_images-0069.png
# Epoch [70/300], Step [200/391], d_loss: 1.4144, g_loss: 0.9393, D(x): 0.42, D(G(z)): 0.43
# Saving fake_images-0070.png
# Epoch [71/300], Step [200/391], d_loss: 1.3653, g_loss: 1.1040, D(x): 0.40, D(G(z)): 0.37
# Saving fake_images-0071.png
# Epoch [72/300], Step [200/391], d_loss: 1.3439, g_loss: 1.0568, D(x): 0.41, D(G(z)): 0.37
# Saving fake_images-0072.png
# Epoch [73/300], Step [200/391], d_loss: 1.2988, g_loss: 0.9467, D(x): 0.46, D(G(z)): 0.41
# Saving fake_images-0073.png
# Epoch [74/300], Step [200/391], d_loss: 1.4756, g_loss: 0.9546, D(x): 0.36, D(G(z)): 0.37
# Saving fake_images-0074.png
# Epoch [75/300], Step [200/391], d_loss: 1.4815, g_loss: 1.0131, D(x): 0.38, D(G(z)): 0.41
# Saving fake_images-0075.png
# Epoch [76/300], Step [200/391], d_loss: 1.3091, g_loss: 0.9566, D(x): 0.44, D(G(z)): 0.40
# Saving fake_images-0076.png
# Epoch [77/300], Step [200/391], d_loss: 1.4384, g_loss: 0.9412, D(x): 0.38, D(G(z)): 0.40
# Saving fake_images-0077.png
# Epoch [78/300], Step [200/391], d_loss: 1.2938, g_loss: 0.9919, D(x): 0.43, D(G(z)): 0.38
# Saving fake_images-0078.png
# Epoch [79/300], Step [200/391], d_loss: 1.2101, g_loss: 1.0469, D(x): 0.46, D(G(z)): 0.35
# Saving fake_images-0079.png
# Epoch [80/300], Step [200/391], d_loss: 1.3530, g_loss: 1.0452, D(x): 0.40, D(G(z)): 0.37
# Saving fake_images-0080.png
# Epoch [81/300], Step [200/391], d_loss: 1.3563, g_loss: 0.9793, D(x): 0.41, D(G(z)): 0.40
# Saving fake_images-0081.png
# Epoch [82/300], Step [200/391], d_loss: 1.1712, g_loss: 1.0617, D(x): 0.52, D(G(z)): 0.37
# Saving fake_images-0082.png
# Epoch [83/300], Step [200/391], d_loss: 1.2945, g_loss: 0.9178, D(x): 0.45, D(G(z)): 0.40
# Saving fake_images-0083.png
# Epoch [84/300], Step [200/391], d_loss: 1.3238, g_loss: 0.9974, D(x): 0.46, D(G(z)): 0.41
# Saving fake_images-0084.png
# Epoch [85/300], Step [200/391], d_loss: 1.2663, g_loss: 0.9615, D(x): 0.46, D(G(z)): 0.39
# Saving fake_images-0085.png
# Epoch [86/300], Step [200/391], d_loss: 1.4452, g_loss: 0.9684, D(x): 0.41, D(G(z)): 0.43
# Saving fake_images-0086.png
# Epoch [87/300], Step [200/391], d_loss: 1.3392, g_loss: 1.0132, D(x): 0.41, D(G(z)): 0.38
# Saving fake_images-0087.png
# Epoch [88/300], Step [200/391], d_loss: 1.3248, g_loss: 1.0629, D(x): 0.42, D(G(z)): 0.37
# Saving fake_images-0088.png
# Epoch [89/300], Step [200/391], d_loss: 1.4490, g_loss: 0.8858, D(x): 0.45, D(G(z)): 0.45
# Saving fake_images-0089.png
# Epoch [90/300], Step [200/391], d_loss: 1.3906, g_loss: 1.0157, D(x): 0.41, D(G(z)): 0.41
# Saving fake_images-0090.png
# Epoch [91/300], Step [200/391], d_loss: 1.4046, g_loss: 0.9792, D(x): 0.40, D(G(z)): 0.40
# Saving fake_images-0091.png
# Epoch [92/300], Step [200/391], d_loss: 1.3740, g_loss: 1.0159, D(x): 0.40, D(G(z)): 0.39
# Saving fake_images-0092.png
# Epoch [93/300], Step [200/391], d_loss: 1.2976, g_loss: 0.9660, D(x): 0.47, D(G(z)): 0.43
# Saving fake_images-0093.png
# Epoch [94/300], Step [200/391], d_loss: 1.3212, g_loss: 0.9784, D(x): 0.44, D(G(z)): 0.39
# Saving fake_images-0094.png
# Epoch [95/300], Step [200/391], d_loss: 1.4446, g_loss: 0.9816, D(x): 0.38, D(G(z)): 0.40
# Saving fake_images-0095.png
# Epoch [96/300], Step [200/391], d_loss: 1.3237, g_loss: 0.9536, D(x): 0.46, D(G(z)): 0.40
# Saving fake_images-0096.png
# Epoch [97/300], Step [200/391], d_loss: 1.3140, g_loss: 1.1469, D(x): 0.42, D(G(z)): 0.37
# Saving fake_images-0097.png
# Epoch [98/300], Step [200/391], d_loss: 1.2960, g_loss: 1.0593, D(x): 0.43, D(G(z)): 0.38
# Saving fake_images-0098.png
# Epoch [99/300], Step [200/391], d_loss: 1.3883, g_loss: 1.0659, D(x): 0.41, D(G(z)): 0.40
# Saving fake_images-0099.png
# Epoch [100/300], Step [200/391], d_loss: 1.4088, g_loss: 0.9289, D(x): 0.43, D(G(z)): 0.42
# Saving fake_images-0100.png
# Epoch [101/300], Step [200/391], d_loss: 1.2986, g_loss: 0.9202, D(x): 0.45, D(G(z)): 0.40
# Saving fake_images-0101.png
# Epoch [102/300], Step [200/391], d_loss: 1.3269, g_loss: 1.0961, D(x): 0.40, D(G(z)): 0.35
# Saving fake_images-0102.png
# Epoch [103/300], Step [200/391], d_loss: 1.3051, g_loss: 1.0467, D(x): 0.41, D(G(z)): 0.37
# Saving fake_images-0103.png
# Epoch [104/300], Step [200/391], d_loss: 1.5401, g_loss: 0.8770, D(x): 0.42, D(G(z)): 0.47
# Saving fake_images-0104.png
# Epoch [105/300], Step [200/391], d_loss: 1.2830, g_loss: 1.0567, D(x): 0.46, D(G(z)): 0.39
# Saving fake_images-0105.png
# Epoch [106/300], Step [200/391], d_loss: 1.3258, g_loss: 1.0921, D(x): 0.42, D(G(z)): 0.36
# Saving fake_images-0106.png
# Epoch [107/300], Step [200/391], d_loss: 1.2015, g_loss: 1.0509, D(x): 0.50, D(G(z)): 0.39
# Saving fake_images-0107.png
# Epoch [108/300], Step [200/391], d_loss: 1.2619, g_loss: 1.0484, D(x): 0.45, D(G(z)): 0.38
# Saving fake_images-0108.png
# Epoch [109/300], Step [200/391], d_loss: 1.2455, g_loss: 0.9394, D(x): 0.47, D(G(z)): 0.39
# Saving fake_images-0109.png
# Epoch [110/300], Step [200/391], d_loss: 1.2727, g_loss: 1.3354, D(x): 0.40, D(G(z)): 0.31
# Saving fake_images-0110.png
# Epoch [111/300], Step [200/391], d_loss: 1.0360, g_loss: 1.1983, D(x): 0.48, D(G(z)): 0.29
# Saving fake_images-0111.png
# Epoch [112/300], Step [200/391], d_loss: 1.2781, g_loss: 1.0330, D(x): 0.42, D(G(z)): 0.35
# Saving fake_images-0112.png
# Epoch [113/300], Step [200/391], d_loss: 1.2997, g_loss: 1.1451, D(x): 0.40, D(G(z)): 0.35
# Saving fake_images-0113.png
# Epoch [114/300], Step [200/391], d_loss: 1.3522, g_loss: 1.0166, D(x): 0.38, D(G(z)): 0.36
# Saving fake_images-0114.png
# Epoch [115/300], Step [200/391], d_loss: 1.0758, g_loss: 1.1825, D(x): 0.50, D(G(z)): 0.35
# Saving fake_images-0115.png
# Epoch [116/300], Step [200/391], d_loss: 1.2520, g_loss: 1.2433, D(x): 0.46, D(G(z)): 0.38
# Saving fake_images-0116.png
# Epoch [117/300], Step [200/391], d_loss: 1.2521, g_loss: 1.1626, D(x): 0.41, D(G(z)): 0.33
# Saving fake_images-0117.png
# Epoch [118/300], Step [200/391], d_loss: 1.2720, g_loss: 1.0305, D(x): 0.48, D(G(z)): 0.40
# Saving fake_images-0118.png
# Epoch [119/300], Step [200/391], d_loss: 1.2274, g_loss: 1.0241, D(x): 0.46, D(G(z)): 0.36
# Saving fake_images-0119.png
# Epoch [120/300], Step [200/391], d_loss: 1.3299, g_loss: 1.0447, D(x): 0.46, D(G(z)): 0.40
# Saving fake_images-0120.png
# Epoch [121/300], Step [200/391], d_loss: 1.0722, g_loss: 0.9810, D(x): 0.51, D(G(z)): 0.32
# Saving fake_images-0121.png
# Epoch [122/300], Step [200/391], d_loss: 1.1473, g_loss: 1.3818, D(x): 0.48, D(G(z)): 0.34
# Saving fake_images-0122.png
# Epoch [123/300], Step [200/391], d_loss: 1.2282, g_loss: 1.1908, D(x): 0.48, D(G(z)): 0.37
# Saving fake_images-0123.png
# Epoch [124/300], Step [200/391], d_loss: 1.3709, g_loss: 1.0023, D(x): 0.43, D(G(z)): 0.40
# Saving fake_images-0124.png
# Epoch [125/300], Step [200/391], d_loss: 1.0468, g_loss: 1.1552, D(x): 0.50, D(G(z)): 0.32
# Saving fake_images-0125.png
# Epoch [126/300], Step [200/391], d_loss: 1.3244, g_loss: 0.9086, D(x): 0.45, D(G(z)): 0.36
# Saving fake_images-0126.png
# Epoch [127/300], Step [200/391], d_loss: 1.2616, g_loss: 0.9956, D(x): 0.46, D(G(z)): 0.38
# Saving fake_images-0127.png
# Epoch [128/300], Step [200/391], d_loss: 1.0719, g_loss: 1.1866, D(x): 0.47, D(G(z)): 0.30
# Saving fake_images-0128.png
# Epoch [129/300], Step [200/391], d_loss: 0.9513, g_loss: 1.6319, D(x): 0.45, D(G(z)): 0.24
# Saving fake_images-0129.png
# Epoch [130/300], Step [200/391], d_loss: 1.0870, g_loss: 1.3603, D(x): 0.47, D(G(z)): 0.28
# Saving fake_images-0130.png
# Epoch [131/300], Step [200/391], d_loss: 1.0228, g_loss: 1.5501, D(x): 0.46, D(G(z)): 0.25
# Saving fake_images-0131.png
# Epoch [132/300], Step [200/391], d_loss: 1.2788, g_loss: 1.2059, D(x): 0.44, D(G(z)): 0.34
# Saving fake_images-0132.png
# Epoch [133/300], Step [200/391], d_loss: 1.1170, g_loss: 0.9715, D(x): 0.53, D(G(z)): 0.37
# Saving fake_images-0133.png
# Epoch [134/300], Step [200/391], d_loss: 1.1559, g_loss: 1.3582, D(x): 0.42, D(G(z)): 0.24
# Saving fake_images-0134.png
# Epoch [135/300], Step [200/391], d_loss: 1.1328, g_loss: 1.0775, D(x): 0.53, D(G(z)): 0.38
# Saving fake_images-0135.png
# Epoch [136/300], Step [200/391], d_loss: 1.1258, g_loss: 1.0972, D(x): 0.51, D(G(z)): 0.35
# Saving fake_images-0136.png
# Epoch [137/300], Step [200/391], d_loss: 0.8766, g_loss: 1.3885, D(x): 0.49, D(G(z)): 0.22
# Saving fake_images-0137.png
# Epoch [138/300], Step [200/391], d_loss: 1.1634, g_loss: 1.2792, D(x): 0.48, D(G(z)): 0.34
# Saving fake_images-0138.png
# Epoch [139/300], Step [200/391], d_loss: 0.9916, g_loss: 1.6244, D(x): 0.53, D(G(z)): 0.28
# Saving fake_images-0139.png
# Epoch [140/300], Step [200/391], d_loss: 0.8298, g_loss: 1.4841, D(x): 0.63, D(G(z)): 0.30
# Saving fake_images-0140.png
# Epoch [141/300], Step [200/391], d_loss: 1.0887, g_loss: 1.1676, D(x): 0.53, D(G(z)): 0.35
# Saving fake_images-0141.png
# Epoch [142/300], Step [200/391], d_loss: 0.8600, g_loss: 1.7689, D(x): 0.48, D(G(z)): 0.21
# Saving fake_images-0142.png
# Epoch [143/300], Step [200/391], d_loss: 1.0622, g_loss: 1.5780, D(x): 0.66, D(G(z)): 0.43
# Saving fake_images-0143.png
# Epoch [144/300], Step [200/391], d_loss: 1.1391, g_loss: 1.0347, D(x): 0.48, D(G(z)): 0.34
# Saving fake_images-0144.png
# Epoch [145/300], Step [200/391], d_loss: 0.7369, g_loss: 1.3960, D(x): 0.66, D(G(z)): 0.23
# Saving fake_images-0145.png
# Epoch [146/300], Step [200/391], d_loss: 1.0132, g_loss: 1.5527, D(x): 0.60, D(G(z)): 0.36
# Saving fake_images-0146.png
# Epoch [147/300], Step [200/391], d_loss: 1.1687, g_loss: 1.2625, D(x): 0.61, D(G(z)): 0.42
# Saving fake_images-0147.png
# Epoch [148/300], Step [200/391], d_loss: 1.2232, g_loss: 1.5759, D(x): 0.49, D(G(z)): 0.37
# Saving fake_images-0148.png
# Epoch [149/300], Step [200/391], d_loss: 0.9941, g_loss: 1.3898, D(x): 0.59, D(G(z)): 0.31
# Saving fake_images-0149.png
# Epoch [150/300], Step [200/391], d_loss: 1.4217, g_loss: 1.9474, D(x): 0.31, D(G(z)): 0.23
# Saving fake_images-0150.png
# Epoch [151/300], Step [200/391], d_loss: 1.1957, g_loss: 1.3737, D(x): 0.41, D(G(z)): 0.26
# Saving fake_images-0151.png
# Epoch [152/300], Step [200/391], d_loss: 0.8425, g_loss: 1.4180, D(x): 0.55, D(G(z)): 0.23
# Saving fake_images-0152.png
# Epoch [153/300], Step [200/391], d_loss: 1.1043, g_loss: 1.9086, D(x): 0.34, D(G(z)): 0.17
# Saving fake_images-0153.png
# Epoch [154/300], Step [200/391], d_loss: 0.7275, g_loss: 1.9063, D(x): 0.57, D(G(z)): 0.20
# Saving fake_images-0154.png
# Epoch [155/300], Step [200/391], d_loss: 0.7402, g_loss: 1.8056, D(x): 0.66, D(G(z)): 0.27
# Saving fake_images-0155.png
# Epoch [156/300], Step [200/391], d_loss: 0.8695, g_loss: 1.7996, D(x): 0.51, D(G(z)): 0.22
# Saving fake_images-0156.png
# Epoch [157/300], Step [200/391], d_loss: 0.9942, g_loss: 1.6176, D(x): 0.52, D(G(z)): 0.25
# Saving fake_images-0157.png
# Epoch [158/300], Step [200/391], d_loss: 0.7217, g_loss: 1.8369, D(x): 0.63, D(G(z)): 0.17
# Saving fake_images-0158.png
# Epoch [159/300], Step [200/391], d_loss: 0.8534, g_loss: 2.0534, D(x): 0.62, D(G(z)): 0.27
# Saving fake_images-0159.png
# Epoch [160/300], Step [200/391], d_loss: 0.8291, g_loss: 1.2544, D(x): 0.72, D(G(z)): 0.37
# Saving fake_images-0160.png
# Epoch [161/300], Step [200/391], d_loss: 1.2628, g_loss: 1.8050, D(x): 0.60, D(G(z)): 0.46
# Saving fake_images-0161.png
# Epoch [162/300], Step [200/391], d_loss: 0.9872, g_loss: 1.5158, D(x): 0.58, D(G(z)): 0.27
# Saving fake_images-0162.png
# Epoch [163/300], Step [200/391], d_loss: 0.9006, g_loss: 1.8271, D(x): 0.49, D(G(z)): 0.19
# Saving fake_images-0163.png
# Epoch [164/300], Step [200/391], d_loss: 0.8227, g_loss: 2.2074, D(x): 0.48, D(G(z)): 0.15
# Saving fake_images-0164.png
# Epoch [165/300], Step [200/391], d_loss: 0.5598, g_loss: 1.6465, D(x): 0.67, D(G(z)): 0.18
# Saving fake_images-0165.png
# Epoch [166/300], Step [200/391], d_loss: 0.5912, g_loss: 1.6449, D(x): 0.69, D(G(z)): 0.20
# Epoch [167/300], Step [200/391], d_loss: 0.7886, g_loss: 1.8881, D(x): 0.51, D(G(z)): 0.14
# Saving fake_images-0167.png
# Epoch [168/300], Step [200/391], d_loss: 0.7282, g_loss: 1.2420, D(x): 0.71, D(G(z)): 0.31
# Saving fake_images-0168.png
# Epoch [169/300], Step [200/391], d_loss: 0.9211, g_loss: 1.5735, D(x): 0.46, D(G(z)): 0.20
# Saving fake_images-0169.png
# Epoch [170/300], Step [200/391], d_loss: 1.2289, g_loss: 1.4310, D(x): 0.49, D(G(z)): 0.36
# Saving fake_images-0170.png
# Epoch [171/300], Step [200/391], d_loss: 0.9880, g_loss: 1.5920, D(x): 0.57, D(G(z)): 0.29
# Saving fake_images-0171.png
# Epoch [172/300], Step [200/391], d_loss: 0.8284, g_loss: 2.2075, D(x): 0.45, D(G(z)): 0.13
# Saving fake_images-0172.png
# Epoch [173/300], Step [200/391], d_loss: 0.7326, g_loss: 2.0294, D(x): 0.56, D(G(z)): 0.15
# Saving fake_images-0173.png
# Epoch [174/300], Step [200/391], d_loss: 0.5433, g_loss: 0.7957, D(x): 0.70, D(G(z)): 0.16
# Saving fake_images-0174.png
# Epoch [175/300], Step [200/391], d_loss: 0.7939, g_loss: 1.8831, D(x): 0.63, D(G(z)): 0.26
# Saving fake_images-0175.png
# Epoch [176/300], Step [200/391], d_loss: 0.7628, g_loss: 2.2018, D(x): 0.73, D(G(z)): 0.21
# Saving fake_images-0176.png
# Epoch [177/300], Step [200/391], d_loss: 1.0160, g_loss: 1.4138, D(x): 0.67, D(G(z)): 0.34
# Saving fake_images-0177.png
# Epoch [178/300], Step [200/391], d_loss: 0.7364, g_loss: 1.8095, D(x): 0.67, D(G(z)): 0.28
# Saving fake_images-0178.png
# Epoch [179/300], Step [200/391], d_loss: 0.5931, g_loss: 1.7720, D(x): 0.63, D(G(z)): 0.18
# Saving fake_images-0179.png
# Epoch [180/300], Step [200/391], d_loss: 0.6605, g_loss: 0.9173, D(x): 0.74, D(G(z)): 0.28
# Saving fake_images-0180.png
# Epoch [181/300], Step [200/391], d_loss: 0.8240, g_loss: 2.0695, D(x): 0.47, D(G(z)): 0.15
# Saving fake_images-0181.png
# Epoch [182/300], Step [200/391], d_loss: 0.4197, g_loss: 1.9237, D(x): 0.63, D(G(z)): 0.09
# Saving fake_images-0182.png
# Epoch [183/300], Step [200/391], d_loss: 0.6607, g_loss: 2.4282, D(x): 0.61, D(G(z)): 0.07
# Saving fake_images-0183.png
# Epoch [184/300], Step [200/391], d_loss: 0.4851, g_loss: 1.1701, D(x): 0.84, D(G(z)): 0.15
# Saving fake_images-0184.png
# Epoch [185/300], Step [200/391], d_loss: 1.0805, g_loss: 2.0053, D(x): 0.32, D(G(z)): 0.11
# Saving fake_images-0185.png
# Epoch [186/300], Step [200/391], d_loss: 1.0001, g_loss: 0.7017, D(x): 0.48, D(G(z)): 0.23
# Saving fake_images-0186.png
# Epoch [187/300], Step [200/391], d_loss: 0.8796, g_loss: 1.3176, D(x): 0.56, D(G(z)): 0.27
# Saving fake_images-0187.png
# Epoch [188/300], Step [200/391], d_loss: 1.2009, g_loss: 1.6875, D(x): 0.34, D(G(z)): 0.14
# Saving fake_images-0188.png
# Epoch [189/300], Step [200/391], d_loss: 1.0138, g_loss: 1.0148, D(x): 0.62, D(G(z)): 0.38
# Saving fake_images-0189.png
# Epoch [190/300], Step [200/391], d_loss: 0.5316, g_loss: 2.0208, D(x): 0.72, D(G(z)): 0.17
# Saving fake_images-0190.png
# Epoch [191/300], Step [200/391], d_loss: 0.7570, g_loss: 1.7349, D(x): 0.71, D(G(z)): 0.27
# Saving fake_images-0191.png
# Epoch [192/300], Step [200/391], d_loss: 0.9211, g_loss: 2.0182, D(x): 0.42, D(G(z)): 0.14
# Saving fake_images-0192.png
# Epoch [193/300], Step [200/391], d_loss: 0.6564, g_loss: 1.4072, D(x): 0.64, D(G(z)): 0.19
# Saving fake_images-0193.png
# Epoch [194/300], Step [200/391], d_loss: 0.6093, g_loss: 1.7811, D(x): 0.74, D(G(z)): 0.26
# Saving fake_images-0194.png
# Epoch [195/300], Step [200/391], d_loss: 0.9805, g_loss: 2.1399, D(x): 0.37, D(G(z)): 0.12
# Saving fake_images-0195.png
# Epoch [196/300], Step [200/391], d_loss: 1.0686, g_loss: 1.4168, D(x): 0.49, D(G(z)): 0.28
# Saving fake_images-0196.png
# Epoch [197/300], Step [200/391], d_loss: 0.6920, g_loss: 1.7354, D(x): 0.83, D(G(z)): 0.29
# Saving fake_images-0197.png
# Epoch [198/300], Step [200/391], d_loss: 0.4767, g_loss: 2.2701, D(x): 0.61, D(G(z)): 0.14
# Saving fake_images-0198.png
# Epoch [199/300], Step [200/391], d_loss: 0.9233, g_loss: 1.8829, D(x): 0.39, D(G(z)): 0.10
# Saving fake_images-0199.png
# Epoch [200/300], Step [200/391], d_loss: 0.5952, g_loss: 1.5732, D(x): 0.83, D(G(z)): 0.30
# Saving fake_images-0200.png
# Epoch [201/300], Step [200/391], d_loss: 0.7309, g_loss: 1.5229, D(x): 0.81, D(G(z)): 0.29
# Saving fake_images-0201.png
# Epoch [202/300], Step [200/391], d_loss: 0.5021, g_loss: 1.4687, D(x): 0.63, D(G(z)): 0.12
# Saving fake_images-0202.png
# Epoch [203/300], Step [200/391], d_loss: 0.3499, g_loss: 1.5463, D(x): 0.73, D(G(z)): 0.08
# Saving fake_images-0203.png
# Epoch [204/300], Step [200/391], d_loss: 0.8152, g_loss: 2.2615, D(x): 0.81, D(G(z)): 0.32
# Saving fake_images-0204.png
# Epoch [205/300], Step [200/391], d_loss: 0.8675, g_loss: 1.2547, D(x): 0.51, D(G(z)): 0.13
# Saving fake_images-0205.png
# Epoch [206/300], Step [200/391], d_loss: 0.6534, g_loss: 2.9165, D(x): 0.43, D(G(z)): 0.08
# Saving fake_images-0206.png
# Epoch [207/300], Step [200/391], d_loss: 1.1175, g_loss: 2.8261, D(x): 0.39, D(G(z)): 0.21
# Saving fake_images-0207.png
# Epoch [208/300], Step [200/391], d_loss: 0.7348, g_loss: 2.3514, D(x): 0.66, D(G(z)): 0.22
# Saving fake_images-0208.png
# Epoch [209/300], Step [200/391], d_loss: 0.4592, g_loss: 1.4867, D(x): 0.74, D(G(z)): 0.21
# Saving fake_images-0209.png
# Epoch [210/300], Step [200/391], d_loss: 1.0447, g_loss: 2.3499, D(x): 0.73, D(G(z)): 0.42
# Saving fake_images-0210.png
# Epoch [211/300], Step [200/391], d_loss: 1.0018, g_loss: 1.4566, D(x): 0.45, D(G(z)): 0.16
# Saving fake_images-0211.png
# Epoch [212/300], Step [200/391], d_loss: 1.0990, g_loss: 2.1821, D(x): 0.37, D(G(z)): 0.15
# Saving fake_images-0212.png
# Epoch [213/300], Step [200/391], d_loss: 1.6001, g_loss: 2.1598, D(x): 0.69, D(G(z)): 0.63
# Saving fake_images-0213.png
# Epoch [214/300], Step [200/391], d_loss: 0.8035, g_loss: 3.1183, D(x): 0.59, D(G(z)): 0.27
# Saving fake_images-0214.png
# Epoch [215/300], Step [200/391], d_loss: 1.2770, g_loss: 1.4618, D(x): 0.68, D(G(z)): 0.50
# Saving fake_images-0215.png
# Epoch [216/300], Step [200/391], d_loss: 0.2568, g_loss: 2.4831, D(x): 0.69, D(G(z)): 0.07
# Saving fake_images-0216.png
# Epoch [217/300], Step [200/391], d_loss: 0.5638, g_loss: 1.4871, D(x): 0.65, D(G(z)): 0.15
# Saving fake_images-0217.png
# Epoch [218/300], Step [200/391], d_loss: 0.8789, g_loss: 3.6443, D(x): 0.51, D(G(z)): 0.18
# Saving fake_images-0218.png
# Epoch [219/300], Step [200/391], d_loss: 0.6082, g_loss: 2.1816, D(x): 0.54, D(G(z)): 0.09
# Saving fake_images-0219.png
# Epoch [220/300], Step [200/391], d_loss: 0.4378, g_loss: 1.2320, D(x): 0.85, D(G(z)): 0.17
# Saving fake_images-0220.png
# Epoch [221/300], Step [200/391], d_loss: 1.0686, g_loss: 1.3903, D(x): 0.38, D(G(z)): 0.14
# Saving fake_images-0221.png
# Epoch [222/300], Step [200/391], d_loss: 0.6823, g_loss: 1.9804, D(x): 0.75, D(G(z)): 0.19
# Saving fake_images-0222.png
# Epoch [223/300], Step [200/391], d_loss: 0.8384, g_loss: 0.9498, D(x): 0.80, D(G(z)): 0.35
# Saving fake_images-0223.png
# Epoch [224/300], Step [200/391], d_loss: 0.2852, g_loss: 2.2049, D(x): 0.75, D(G(z)): 0.08
# Saving fake_images-0224.png
# Epoch [225/300], Step [200/391], d_loss: 0.8377, g_loss: 1.1108, D(x): 0.61, D(G(z)): 0.27
# Saving fake_images-0225.png
# Epoch [226/300], Step [200/391], d_loss: 0.1306, g_loss: 1.9941, D(x): 0.74, D(G(z)): 0.04
# Saving fake_images-0226.png
# Epoch [227/300], Step [200/391], d_loss: 0.8027, g_loss: 1.7786, D(x): 0.63, D(G(z)): 0.26
# Saving fake_images-0227.png
# Epoch [228/300], Step [200/391], d_loss: 0.5468, g_loss: 3.4996, D(x): 0.49, D(G(z)): 0.05
# Saving fake_images-0228.png
# Epoch [229/300], Step [200/391], d_loss: 0.5505, g_loss: 1.5367, D(x): 0.89, D(G(z)): 0.24
# Saving fake_images-0229.png
# Epoch [230/300], Step [200/391], d_loss: 0.4864, g_loss: 2.0095, D(x): 0.81, D(G(z)): 0.09
# Saving fake_images-0230.png
# Epoch [231/300], Step [200/391], d_loss: 0.5556, g_loss: 1.5292, D(x): 0.79, D(G(z)): 0.20
# Saving fake_images-0231.png
# Epoch [232/300], Step [200/391], d_loss: 0.4731, g_loss: 1.3916, D(x): 0.87, D(G(z)): 0.25
# Saving fake_images-0232.png
# Epoch [233/300], Step [200/391], d_loss: 1.0570, g_loss: 2.6432, D(x): 0.52, D(G(z)): 0.31
# Saving fake_images-0233.png
# Epoch [234/300], Step [200/391], d_loss: 0.9519, g_loss: 1.5330, D(x): 0.58, D(G(z)): 0.33
# Saving fake_images-0234.png
# Epoch [235/300], Step [200/391], d_loss: 0.4484, g_loss: 2.4556, D(x): 0.66, D(G(z)): 0.07
# Saving fake_images-0235.png
# Epoch [236/300], Step [200/391], d_loss: 0.5093, g_loss: 1.9115, D(x): 0.79, D(G(z)): 0.25
# Saving fake_images-0236.png
# Epoch [237/300], Step [200/391], d_loss: 0.4356, g_loss: 2.0069, D(x): 0.71, D(G(z)): 0.12
# Saving fake_images-0237.png
# Epoch [238/300], Step [200/391], d_loss: 1.3010, g_loss: 2.3773, D(x): 0.48, D(G(z)): 0.38
# Saving fake_images-0238.png
# Epoch [239/300], Step [200/391], d_loss: 0.6051, g_loss: 2.2426, D(x): 0.55, D(G(z)): 0.10
# Saving fake_images-0239.png
# Epoch [240/300], Step [200/391], d_loss: 0.6592, g_loss: 2.3485, D(x): 0.63, D(G(z)): 0.16
# Saving fake_images-0240.png
# Epoch [241/300], Step [200/391], d_loss: 0.3788, g_loss: 1.8724, D(x): 0.74, D(G(z)): 0.17
# Saving fake_images-0241.png
# Epoch [242/300], Step [200/391], d_loss: 0.5364, g_loss: 2.6935, D(x): 0.69, D(G(z)): 0.10
# Saving fake_images-0242.png
# Epoch [243/300], Step [200/391], d_loss: 0.4379, g_loss: 2.2389, D(x): 0.68, D(G(z)): 0.08
# Saving fake_images-0243.png
# Epoch [244/300], Step [200/391], d_loss: 0.2376, g_loss: 2.4241, D(x): 0.73, D(G(z)): 0.05
# Saving fake_images-0244.png
# Epoch [245/300], Step [200/391], d_loss: 0.5167, g_loss: 1.8494, D(x): 0.67, D(G(z)): 0.15
# Saving fake_images-0245.png
# Epoch [246/300], Step [200/391], d_loss: 0.4016, g_loss: 2.2790, D(x): 0.56, D(G(z)): 0.07
# Saving fake_images-0246.png
# Epoch [247/300], Step [200/391], d_loss: 0.6065, g_loss: 3.2331, D(x): 0.52, D(G(z)): 0.07
# Saving fake_images-0247.png
# Epoch [248/300], Step [200/391], d_loss: 0.5392, g_loss: 1.6162, D(x): 0.52, D(G(z)): 0.09
# Saving fake_images-0248.png
# Epoch [249/300], Step [200/391], d_loss: 1.8431, g_loss: 2.2727, D(x): 0.21, D(G(z)): 0.23
# Saving fake_images-0249.png
# Epoch [250/300], Step [200/391], d_loss: 0.8159, g_loss: 3.4186, D(x): 0.45, D(G(z)): 0.09
# Saving fake_images-0250.png
# Epoch [251/300], Step [200/391], d_loss: 0.4231, g_loss: 2.3249, D(x): 0.77, D(G(z)): 0.17
# Saving fake_images-0251.png
# Epoch [252/300], Step [200/391], d_loss: 0.3122, g_loss: 1.4946, D(x): 0.84, D(G(z)): 0.15
# Saving fake_images-0252.png
# Epoch [253/300], Step [200/391], d_loss: 0.2681, g_loss: 2.7852, D(x): 0.75, D(G(z)): 0.06
# Saving fake_images-0253.png
# Epoch [254/300], Step [200/391], d_loss: 0.5419, g_loss: 2.3513, D(x): 0.58, D(G(z)): 0.09
# Saving fake_images-0254.png
# Epoch [255/300], Step [200/391], d_loss: 0.3436, g_loss: 1.5920, D(x): 0.78, D(G(z)): 0.12
# Saving fake_images-0255.png
# Epoch [256/300], Step [200/391], d_loss: 1.0143, g_loss: 2.9051, D(x): 0.28, D(G(z)): 0.05
# Saving fake_images-0256.png
# Epoch [257/300], Step [200/391], d_loss: 1.6673, g_loss: 3.7728, D(x): 0.24, D(G(z)): 0.23
# Saving fake_images-0257.png
# Epoch [258/300], Step [200/391], d_loss: 0.4596, g_loss: 2.6649, D(x): 0.62, D(G(z)): 0.13
# Saving fake_images-0258.png
# Epoch [259/300], Step [200/391], d_loss: 0.6394, g_loss: 3.0898, D(x): 0.49, D(G(z)): 0.10
# Saving fake_images-0259.png
# Epoch [260/300], Step [200/391], d_loss: 0.6226, g_loss: 1.3215, D(x): 0.85, D(G(z)): 0.25
# Saving fake_images-0260.png
# Epoch [261/300], Step [200/391], d_loss: 0.3873, g_loss: 3.2443, D(x): 0.66, D(G(z)): 0.09
# Saving fake_images-0261.png
# Epoch [262/300], Step [200/391], d_loss: 0.3593, g_loss: 3.8069, D(x): 0.78, D(G(z)): 0.12
# Saving fake_images-0262.png
# Epoch [263/300], Step [200/391], d_loss: 0.3312, g_loss: 2.5172, D(x): 0.74, D(G(z)): 0.07
# Saving fake_images-0263.png
# Epoch [264/300], Step [200/391], d_loss: 0.6996, g_loss: 1.8337, D(x): 0.50, D(G(z)): 0.11
# Saving fake_images-0264.png
# Epoch [265/300], Step [200/391], d_loss: 0.3367, g_loss: 3.4911, D(x): 0.89, D(G(z)): 0.08
# Saving fake_images-0265.png
# Epoch [266/300], Step [200/391], d_loss: 0.8900, g_loss: 2.0593, D(x): 0.83, D(G(z)): 0.40
# Saving fake_images-0266.png
# Epoch [267/300], Step [200/391], d_loss: 0.5826, g_loss: 1.6517, D(x): 0.69, D(G(z)): 0.12
# Saving fake_images-0267.png
# Epoch [268/300], Step [200/391], d_loss: 0.6660, g_loss: 2.2422, D(x): 0.90, D(G(z)): 0.27
# Saving fake_images-0268.png
# Epoch [269/300], Step [200/391], d_loss: 1.3042, g_loss: 3.6738, D(x): 0.25, D(G(z)): 0.07
# Saving fake_images-0269.png
# Epoch [270/300], Step [200/391], d_loss: 0.4049, g_loss: 1.8741, D(x): 0.69, D(G(z)): 0.14
# Saving fake_images-0270.png
# Epoch [271/300], Step [200/391], d_loss: 0.5952, g_loss: 2.2127, D(x): 0.88, D(G(z)): 0.21
# Saving fake_images-0271.png
# Epoch [272/300], Step [200/391], d_loss: 1.0369, g_loss: 3.8526, D(x): 0.40, D(G(z)): 0.13
# Saving fake_images-0272.png
# Epoch [273/300], Step [200/391], d_loss: 0.5171, g_loss: 2.0495, D(x): 0.71, D(G(z)): 0.16
# Saving fake_images-0273.png
# Epoch [274/300], Step [200/391], d_loss: 0.6776, g_loss: 0.8696, D(x): 0.82, D(G(z)): 0.30
# Saving fake_images-0274.png
# Epoch [275/300], Step [200/391], d_loss: 0.5310, g_loss: 3.2321, D(x): 0.74, D(G(z)): 0.13
# Saving fake_images-0275.png
# Epoch [276/300], Step [200/391], d_loss: 0.6489, g_loss: 3.1921, D(x): 0.41, D(G(z)): 0.05
# Saving fake_images-0276.png
# Epoch [277/300], Step [200/391], d_loss: 0.7659, g_loss: 2.4615, D(x): 0.78, D(G(z)): 0.33
# Saving fake_images-0277.png
# Epoch [278/300], Step [200/391], d_loss: 0.3601, g_loss: 2.7212, D(x): 0.87, D(G(z)): 0.11
# Saving fake_images-0278.png
# Epoch [279/300], Step [200/391], d_loss: 0.1709, g_loss: 2.7170, D(x): 0.75, D(G(z)): 0.05
# Saving fake_images-0279.png
# Epoch [280/300], Step [200/391], d_loss: 0.1359, g_loss: 2.3094, D(x): 0.70, D(G(z)): 0.03
# Saving fake_images-0280.png
# Epoch [281/300], Step [200/391], d_loss: 0.8153, g_loss: 2.1595, D(x): 0.46, D(G(z)): 0.16
# Saving fake_images-0281.png
# Epoch [282/300], Step [200/391], d_loss: 0.2763, g_loss: 1.4814, D(x): 0.93, D(G(z)): 0.20
# Saving fake_images-0282.png
# Epoch [283/300], Step [200/391], d_loss: 0.2844, g_loss: 3.9054, D(x): 0.72, D(G(z)): 0.07
# Saving fake_images-0283.png
# Epoch [284/300], Step [200/391], d_loss: 0.7163, g_loss: 2.4321, D(x): 0.42, D(G(z)): 0.09
# Saving fake_images-0284.png
# Epoch [285/300], Step [200/391], d_loss: 0.5098, g_loss: 4.5399, D(x): 0.75, D(G(z)): 0.10
# Saving fake_images-0285.png
# Epoch [286/300], Step [200/391], d_loss: 0.2102, g_loss: 1.5123, D(x): 0.85, D(G(z)): 0.11
# Saving fake_images-0286.png
# Epoch [287/300], Step [200/391], d_loss: 0.7283, g_loss: 1.5889, D(x): 0.87, D(G(z)): 0.31
# Saving fake_images-0287.png
# Epoch [288/300], Step [200/391], d_loss: 0.9574, g_loss: 2.9916, D(x): 0.36, D(G(z)): 0.09
# Saving fake_images-0288.png
# Epoch [289/300], Step [200/391], d_loss: 0.3567, g_loss: 1.6804, D(x): 0.94, D(G(z)): 0.11
# Saving fake_images-0289.png
# Epoch [290/300], Step [200/391], d_loss: 0.1998, g_loss: 1.8985, D(x): 0.72, D(G(z)): 0.05
# Saving fake_images-0290.png
# Epoch [291/300], Step [200/391], d_loss: 0.5778, g_loss: 1.6209, D(x): 0.48, D(G(z)): 0.06
# Saving fake_images-0291.png
# Epoch [292/300], Step [200/391], d_loss: 0.4011, g_loss: 3.1669, D(x): 0.83, D(G(z)): 0.19
# Saving fake_images-0292.png
# Epoch [293/300], Step [200/391], d_loss: 0.5261, g_loss: 3.3437, D(x): 0.90, D(G(z)): 0.22
# Saving fake_images-0293.png
# Epoch [294/300], Step [200/391], d_loss: 0.2609, g_loss: 2.3894, D(x): 0.55, D(G(z)): 0.04
# Saving fake_images-0294.png
# Epoch [295/300], Step [200/391], d_loss: 0.1494, g_loss: 2.6787, D(x): 0.87, D(G(z)): 0.14
# Saving fake_images-0295.png
# Epoch [296/300], Step [200/391], d_loss: 0.5417, g_loss: 1.9148, D(x): 0.77, D(G(z)): 0.19
# Saving fake_images-0296.png
# Epoch [297/300], Step [200/391], d_loss: 0.3420, g_loss: 4.2917, D(x): 0.83, D(G(z)): 0.17
# Saving fake_images-0297.png
# Epoch [298/300], Step [200/391], d_loss: 0.7050, g_loss: 2.9449, D(x): 0.64, D(G(z)): 0.25
# Saving fake_images-0298.png
# Epoch [299/300], Step [200/391], d_loss: 0.7589, g_loss: 1.9364, D(x): 0.51, D(G(z)): 0.12
# Saving fake_images-0299.png
# Epoch [300/300], Step [200/391], d_loss: 0.5349, g_loss: 2.8605, D(x): 0.39, D(G(z)): 0.04
# Saving fake_images-0300.png
# CPU times: user 2h 16min 4s, sys: 4min 13s, total: 2h 20min 18s
# Wall time: 2h 14min 3s

# %%
Image(os.path.join('/kaggle/working/images', 'fake_images-0125.png'))

# %%
Image(os.path.join('/kaggle/working/images', 'fake_images-0300.png'))

# %%
plt.plot(d_losses, '-')
plt.plot(g_losses, '-')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['Discriminator', 'Generator'])
plt.title('Losses');

# %%
plt.plot(real_scores, '-')
plt.plot(fake_scores, '-')
plt.xlabel('epoch')
plt.ylabel('score')
plt.legend(['Real Score', 'Fake score'])
plt.title('Scores');

# %% [markdown]
# ### install library from https://github.com/w86763777/pytorch-gan-metrics.git
# Currently, this package supports following metrics:
# - Inception Score (IS)
# - Fréchet Inception Distance (FID)

# %%
# clone is repo: https://github.com/w86763777/pytorch-gan-metrics.git and install pytorch-gan-metrics
# !git clone https://github.com/w86763777/pytorch-gan-metrics.git
# !pip install pytorch-gan-metrics
# Out:
# Cloning into 'pytorch-gan-metrics'...
# remote: Enumerating objects: 258, done.
# remote: Counting objects: 100% (28/28), done.
# remote: Compressing objects: 100% (23/23), done.
# remote: Total 258 (delta 7), reused 16 (delta 5), pack-reused 230
# Receiving objects: 100% (258/258), 72.45 KiB | 4.53 MiB/s, done.
# Resolving deltas: 100% (140/140), done.
# Collecting pytorch-gan-metrics
#   Obtaining dependency information for pytorch-gan-metrics from https://files.pythonhosted.org/packages/02/83/2c65b41b01ec26fcd2aea0943f4e2373759314776b9f0a2db9ee59e459cc/pytorch_gan_metrics-0.5.3-py3-none-any.whl.metadata
#   Downloading pytorch_gan_metrics-0.5.3-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from pytorch-gan-metrics) (21.3)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from pytorch-gan-metrics) (4.66.1)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from pytorch-gan-metrics) (1.11.4)
# Requirement already satisfied: torch>=1.8.2 in /opt/conda/lib/python3.10/site-packages (from pytorch-gan-metrics) (2.0.0)
# Requirement already satisfied: torchvision>=0.9.2 in /opt/conda/lib/python3.10/site-packages (from pytorch-gan-metrics) (0.15.1)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.2->pytorch-gan-metrics) (3.12.2)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.2->pytorch-gan-metrics) (4.5.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.2->pytorch-gan-metrics) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.2->pytorch-gan-metrics) (3.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.2->pytorch-gan-metrics) (3.1.2)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from torchvision>=0.9.2->pytorch-gan-metrics) (1.24.3)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from torchvision>=0.9.2->pytorch-gan-metrics) (2.31.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/conda/lib/python3.10/site-packages (from torchvision>=0.9.2->pytorch-gan-metrics) (9.5.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->pytorch-gan-metrics) (3.0.9)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.8.2->pytorch-gan-metrics) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision>=0.9.2->pytorch-gan-metrics) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision>=0.9.2->pytorch-gan-metrics) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision>=0.9.2->pytorch-gan-metrics) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision>=0.9.2->pytorch-gan-metrics) (2023.11.17)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.8.2->pytorch-gan-metrics) (1.3.0)
# Downloading pytorch_gan_metrics-0.5.3-py3-none-any.whl (18 kB)
# Installing collected packages: pytorch-gan-metrics
# Successfully installed pytorch-gan-metrics-0.5.3

# %%
# %cd pytorch-gan-metrics
from pytorch_gan_metrics import (get_inception_score,
                                 get_fid,
                                 get_inception_score_and_fid)
from torch.utils.data import DataLoader
from torchvision.models.inception import inception_v3
import torch
from torch.utils.data import Dataset
# Out:
# [Errno 2] No such file or directory: 'pytorch-gan-metrics'
# /kaggle/working/pytorch-gan-metrics

# %%
 # import function from pytorch_gan_metrics
from pytorch_gan_metrics import (get_inception_score,
                                 get_fid,
                                 get_inception_score_and_fid)

# create the Generator Dataset. returns the image, generated from the Generator network
class GeneratorDataset(Dataset):
    def __init__(self, G, z_dim):
        self.G = G
        self.z_dim = z_dim

    def __len__(self):
        return 500

    def __getitem__(self, index):
        return self.G(torch.randn(1, self.z_dim, 1, 1).cuda())[0]

# define dataset
#create dataloader

# Inception Score
# Frechet Inception Distance
# Inception Score + Frechet Inception Distance

# %%
z_dim = 100
G = Generator(nz=z_dim, ngf=64, nc=3).cuda()
G.eval()

gen_dataset = GeneratorDataset(G, z_dim)
gen_loader = DataLoader(gen_dataset, batch_size=32, shuffle=False)
print("Calculating Inception Score...")
inception_score = get_inception_score(gen_loader)
print("Inception Score:", inception_score)

# Frechet Inception Distance
print("Calculating FID...")

fid = get_fid(gen_loader, '/kaggle/working/cifar-10-fid.npz')
print("FID:", fid)
# Out:
# Calculating Inception Score...
# Inception Score: (6.4917115285565905, 0.0001589515624024655)
# Calculating FID...
# FID: 73.331020405967

# %% [markdown]
# w/o tricks: IS: 6.32, FID: 78
# with tricks: IS: 6.49, FID: 73
